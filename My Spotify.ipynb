# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\riera\anaconda3\lib\site-packages (2.23.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\riera\anaconda3\lib\site-packages (from spotipy) (1.26.11)
# Requirement already satisfied: requests>=2.25.0 in c:\users\riera\anaconda3\lib\site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: redis>=3.5.3 in c:\users\riera\anaconda3\lib\site-packages (from spotipy) (5.0.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\riera\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\riera\anaconda3\lib\site-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2022.9.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time
import datetime

# %%
SPOTIPY_CLIENT_ID = 'd4f68c3fcfdb402caeae8d1e3eea901d'
SPOTIPY_CLIENT_SECRET = '20fe78aa54244addb74de96acda5eb65'
SPOTIPY_REDIRECT_URI = 'http://127.0.0.1:9090'
SCOPE = 'user-top-read'

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID, 
                                               client_secret=SPOTIPY_CLIENT_SECRET, 
                                               redirect_uri=SPOTIPY_REDIRECT_URI, 
                                               scope=SCOPE))

# %%
top_tracks_short = sp.current_user_top_tracks(limit=10,offset=0,time_range='short_term')

# %%
top_tracks_short
# Out:
# {'items': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TjgzYcbTdsZjbT9OItIeB'},
#       'href': 'https://api.spotify.com/v1/artists/2TjgzYcbTdsZjbT9OItIeB',
#       'id': '2TjgzYcbTdsZjbT9OItIeB',
#       'name': 'Héctor "El Father"',
#       'type': 'artist',
#       'uri': 'spotify:artist:2TjgzYcbTdsZjbT9OItIeB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4OapfRPzZGP0iphPp5byyk'},
#     'href': 'https://api.spotify.com/v1/albums/4OapfRPzZGP0iphPp5byyk',
#     'id': '4OapfRPzZGP0iphPp5byyk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736fed3daf437d6ba90a4f8707',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026fed3daf437d6ba90a4f8707',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516fed3daf437d6ba90a4f8707',
#       'width': 64}],
#     'name': 'Goldstar Music La Familia Reggaeton Hits',
#     'release_date': '2019-10-25',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4OapfRPzZGP0iphPp5byyk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TjgzYcbTdsZjbT9OItIeB'},
#      'href': 'https://api.spotify.com/v1/artists/2TjgzYcbTdsZjbT9OItIeB',
#      'id': '2TjgzYcbTdsZjbT9OItIeB',
#      'name': 'Héctor "El Father"',
#      'type': 'artist',
#      'uri': 'spotify:artist:2TjgzYcbTdsZjbT9OItIeB'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 207786,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMRSZ1902149'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1DdrejuwM8C3ExsXaPAgF8'},
#    'href': 'https://api.spotify.com/v1/tracks/1DdrejuwM8C3ExsXaPAgF8',
#    'id': '1DdrejuwM8C3ExsXaPAgF8',
#    'is_local': False,
#    'name': 'Noche de Travesura',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e8c75d3e292ca4bd77c0650e8b90339712dffab2?cid=d4f68c3fcfdb402caeae8d1e3eea901d',
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:1DdrejuwM8C3ExsXaPAgF8'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hHT2BH7XTm3ZdZb6CX064'},
#       'href': 'https://api.spotify.com/v1/artists/0hHT2BH7XTm3ZdZb6CX064',
#       'id': '0hHT2BH7XTm3ZdZb6CX064',
#       'name': 'Raymix',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hHT2BH7XTm3ZdZb6CX064'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6uppp1YRIV4bPZkJoFH8x1'},
#     'href': 'https://api.spotify.com/v1/albums/6uppp1YRIV4bPZkJoFH8x1',
#     'id': '6uppp1YRIV4bPZkJoFH8x1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cb610f9d9d31287af389de3b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cb610f9d9d31287af389de3b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cb610f9d9d31287af389de3b',
#       'width': 64}],
#     'name': 'Oye Mujer',
#     'release_date': '2018-02-07',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:6uppp1YRIV4bPZkJoFH8x1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hHT2BH7XTm3ZdZb6CX064'},
#      'href': 'https://api.spotify.com/v1/artists/0hHT2BH7XTm3ZdZb6CX064',
#      'id': '0hHT2BH7XTm3ZdZb6CX064',
#      'name': 'Raymix',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hHT2BH7XTm3ZdZb6CX064'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 259239,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCADC1712905'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/37kCg5izHEMZ66xGdMVG5L'},
#    'href': 'https://api.spotify.com/v1/tracks/37kCg5izHEMZ66xGdMVG5L',
#    'id': '37kCg5izHEMZ66xGdMVG5L',
#    'is_local': False,
#    'name': 'Oye Mujer',
#    'popularity': 71,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:37kCg5izHEMZ66xGdMVG5L'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7u9m43vPVTERaALXXOzrRq'},
#       'href': 'https://api.spotify.com/v1/artists/7u9m43vPVTERaALXXOzrRq',
#       'id': '7u9m43vPVTERaALXXOzrRq',
#       'name': 'Chalino Sanchez',
#       'type': 'artist',
#       'uri': 'spotify:artist:7u9m43vPVTERaALXXOzrRq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4GmmvkdzlwP5TDac2be0hK'},
#     'href': 'https://api.spotify.com/v1/albums/4GmmvkdzlwP5TDac2be0hK',
#     'id': '4GmmvkdzlwP5TDac2be0hK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736036e5e9db7f583618242eb9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026036e5e9db7f583618242eb9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516036e5e9db7f583618242eb9',
#       'width': 64}],
#     'name': 'Chalino Sánchez con Banda Brava',
#     'release_date': '1993-04-14',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4GmmvkdzlwP5TDac2be0hK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7u9m43vPVTERaALXXOzrRq'},
#      'href': 'https://api.spotify.com/v1/artists/7u9m43vPVTERaALXXOzrRq',
#      'id': '7u9m43vPVTERaALXXOzrRq',
#      'name': 'Chalino Sanchez',
#      'type': 'artist',
#      'uri': 'spotify:artist:7u9m43vPVTERaALXXOzrRq'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7r6kHYuxetBFp0EEKnLHmk'},
#      'href': 'https://api.spotify.com/v1/artists/7r6kHYuxetBFp0EEKnLHmk',
#      'id': '7r6kHYuxetBFp0EEKnLHmk',
#      'name': 'Banda Brava',
#      'type': 'artist',
#      'uri': 'spotify:artist:7r6kHYuxetBFp0EEKnLHmk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 172512,
#    'explicit': False,
#    'external_ids': {'isrc': 'MXF369332438'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6ab5dRx0VtGzMjUejMFI9u'},
#    'href': 'https://api.spotify.com/v1/tracks/6ab5dRx0VtGzMjUejMFI9u',
#    'id': '6ab5dRx0VtGzMjUejMFI9u',
#    'is_local': False,
#    'name': 'Alma Enamorada',
#    'popularity': 69,
#    'preview_url': None,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:6ab5dRx0VtGzMjUejMFI9u'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1FSn3FN1HTxrK4qgoslPJh'},
#       'href': 'https://api.spotify.com/v1/artists/1FSn3FN1HTxrK4qgoslPJh',
#       'id': '1FSn3FN1HTxrK4qgoslPJh',
#       'name': 'Ritmo Y Sabor',
#       'type': 'artist',
#       'uri': 'spotify:artist:1FSn3FN1HTxrK4qgoslPJh'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3a4EAp0gT2IoAvNtToqrCD'},
#     'href': 'https://api.spotify.com/v1/albums/3a4EAp0gT2IoAvNtToqrCD',
#     'id': '3a4EAp0gT2IoAvNtToqrCD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e568a71f17b7df7e44156caa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e568a71f17b7df7e44156caa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e568a71f17b7df7e44156caa',
#       'width': 64}],
#     'name': 'Latino',
#     'release_date': '2015-10-12',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:3a4EAp0gT2IoAvNtToqrCD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1FSn3FN1HTxrK4qgoslPJh'},
#      'href': 'https://api.spotify.com/v1/artists/1FSn3FN1HTxrK4qgoslPJh',
#      'id': '1FSn3FN1HTxrK4qgoslPJh',
#      'name': 'Ritmo Y Sabor',
#      'type': 'artist',
#      'uri': 'spotify:artist:1FSn3FN1HTxrK4qgoslPJh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 202000,
#    'explicit': False,
#    'external_ids': {'isrc': 'QM7281524215'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/03ITeFvMvTRpTC92WsQWw5'},
#    'href': 'https://api.spotify.com/v1/tracks/03ITeFvMvTRpTC92WsQWw5',
#    'id': '03ITeFvMvTRpTC92WsQWw5',
#    'is_local': False,
#    'name': 'La Cumbia de los Monjes',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/87835e9ea0c901144e0c56d0b80a07c449d69782?cid=d4f68c3fcfdb402caeae8d1e3eea901d',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:03ITeFvMvTRpTC92WsQWw5'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7JeWY0pvC27pCgn5eiSeV6'},
#     'href': 'https://api.spotify.com/v1/albums/7JeWY0pvC27pCgn5eiSeV6',
#     'id': '7JeWY0pvC27pCgn5eiSeV6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273522f64d160907ff8a7b61bc7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02522f64d160907ff8a7b61bc7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851522f64d160907ff8a7b61bc7',
#       'width': 64}],
#     'name': 'Talento de Barrio',
#     'release_date': '2008-08-12',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:7JeWY0pvC27pCgn5eiSeV6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#      'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#      'id': '4VMYDCV2IEDYJArk749S6m',
#      'name': 'Daddy Yankee',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 218506,
#    'explicit': False,
#    'external_ids': {'isrc': 'QM7281713567'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0Xfo7PfltbOrAiBs0eSCTH'},
#    'href': 'https://api.spotify.com/v1/tracks/0Xfo7PfltbOrAiBs0eSCTH',
#    'id': '0Xfo7PfltbOrAiBs0eSCTH',
#    'is_local': False,
#    'name': '¿Qué Tengo Que Hacer?',
#    'popularity': 71,
#    'preview_url': 'https://p.scdn.co/mp3-preview/11850c8b7589e9c78f8c70c611266528685a9652?cid=d4f68c3fcfdb402caeae8d1e3eea901d',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:0Xfo7PfltbOrAiBs0eSCTH'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SQdUpG4f7UbkJG3cJ2Iyj'},
#       'href': 'https://api.spotify.com/v1/artists/4SQdUpG4f7UbkJG3cJ2Iyj',
#       'id': '4SQdUpG4f7UbkJG3cJ2Iyj',
#       'name': 'Arca',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SQdUpG4f7UbkJG3cJ2Iyj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1Vg5v9M0afj5sIl1ndRXzy'},
#     'href': 'https://api.spotify.com/v1/albums/1Vg5v9M0afj5sIl1ndRXzy',
#     'id': '1Vg5v9M0afj5sIl1ndRXzy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f9e8f3f889a24247b88cc4a2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f9e8f3f889a24247b88cc4a2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f9e8f3f889a24247b88cc4a2',
#       'width': 64}],
#     'name': 'KICK ii',
#     'release_date': '2021-11-30',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1Vg5v9M0afj5sIl1ndRXzy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SQdUpG4f7UbkJG3cJ2Iyj'},
#      'href': 'https://api.spotify.com/v1/artists/4SQdUpG4f7UbkJG3cJ2Iyj',
#      'id': '4SQdUpG4f7UbkJG3cJ2Iyj',
#      'name': 'Arca',
#      'type': 'artist',
#      'uri': 'spotify:artist:4SQdUpG4f7UbkJG3cJ2Iyj'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 151531,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS2100141'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0hp5IJ83YpnglsrvGfIhIN'},
#    'href': 'https://api.spotify.com/v1/tracks/0hp5IJ83YpnglsrvGfIhIN',
#    'id': '0hp5IJ83YpnglsrvGfIhIN',
#    'is_local': False,
#    'name': 'Rakata',
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0971b002acdd1a51dfe0f5af043ac7ff22bc46ff?cid=d4f68c3fcfdb402caeae8d1e3eea901d',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:0hp5IJ83YpnglsrvGfIhIN'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/01nUdqwuIHCHLZNP2TvYVF'},
#       'href': 'https://api.spotify.com/v1/artists/01nUdqwuIHCHLZNP2TvYVF',
#       'id': '01nUdqwuIHCHLZNP2TvYVF',
#       'name': 'Boy Wonder CF',
#       'type': 'artist',
#       'uri': 'spotify:artist:01nUdqwuIHCHLZNP2TvYVF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/78YSeBn485dP4Lcp3TA3L0'},
#     'href': 'https://api.spotify.com/v1/albums/78YSeBn485dP4Lcp3TA3L0',
#     'id': '78YSeBn485dP4Lcp3TA3L0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736018a9cf19dd63e138222e45',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026018a9cf19dd63e138222e45',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516018a9cf19dd63e138222e45',
#       'width': 64}],
#     'name': 'Boy Wonder Presents Chosen Few Urbano El Journey',
#     'release_date': '2012-09-04',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:78YSeBn485dP4Lcp3TA3L0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/01nUdqwuIHCHLZNP2TvYVF'},
#      'href': 'https://api.spotify.com/v1/artists/01nUdqwuIHCHLZNP2TvYVF',
#      'id': '01nUdqwuIHCHLZNP2TvYVF',
#      'name': 'Boy Wonder CF',
#      'type': 'artist',
#      'uri': 'spotify:artist:01nUdqwuIHCHLZNP2TvYVF'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7wU2WGCJ8HxkekHHE2QLul'},
#      'href': 'https://api.spotify.com/v1/artists/7wU2WGCJ8HxkekHHE2QLul',
#      'id': '7wU2WGCJ8HxkekHHE2QLul',
#      'name': 'Fuego',
#      'type': 'artist',
#      'uri': 'spotify:artist:7wU2WGCJ8HxkekHHE2QLul'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 163760,
#    'explicit': False,
#    'external_ids': {'isrc': 'USASN1202066'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0tsk2L7OXkyjn0X85B5Hhp'},
#    'href': 'https://api.spotify.com/v1/tracks/0tsk2L7OXkyjn0X85B5Hhp',
#    'id': '0tsk2L7OXkyjn0X85B5Hhp',
#    'is_local': False,
#    'name': 'Una Vaina Loca (feat. Fuego)',
#    'popularity': 60,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a7bd399df86451559d1e444619fa6098cd6eda42?cid=d4f68c3fcfdb402caeae8d1e3eea901d',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:0tsk2L7OXkyjn0X85B5Hhp'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/738wLrAtLtCtFOLvQBXOXp'},
#       'href': 'https://api.spotify.com/v1/artists/738wLrAtLtCtFOLvQBXOXp',
#       'id': '738wLrAtLtCtFOLvQBXOXp',
#       'name': 'Major Lazer',
#       'type': 'artist',
#       'uri': 'spotify:artist:738wLrAtLtCtFOLvQBXOXp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5fMUXHkw8R8eOP2RNVYEZX'},
#       'href': 'https://api.spotify.com/v1/artists/5fMUXHkw8R8eOP2RNVYEZX',
#       'id': '5fMUXHkw8R8eOP2RNVYEZX',
#       'name': 'Diplo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5fMUXHkw8R8eOP2RNVYEZX'}],
#     'available_markets': ['CA',
#      'HK',
#      'ID',
#      'IL',
#      'IN',
#      'MX',
#      'MY',
#      'PH',
#      'SG',
#      'TH',
#      'TW',
#      'US',
#      'VN'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/40IcRv5uAg0lpafKsxnQ9g'},
#     'href': 'https://api.spotify.com/v1/albums/40IcRv5uAg0lpafKsxnQ9g',
#     'id': '40IcRv5uAg0lpafKsxnQ9g',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ff1a90a3234b2b344712ff42',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ff1a90a3234b2b344712ff42',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ff1a90a3234b2b344712ff42',
#       'width': 64}],
#     'name': 'Music Is The Weapon (Reloaded)',
#     'release_date': '2021-03-26',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:40IcRv5uAg0lpafKsxnQ9g'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/738wLrAtLtCtFOLvQBXOXp'},
#      'href': 'https://api.spotify.com/v1/artists/738wLrAtLtCtFOLvQBXOXp',
#      'id': '738wLrAtLtCtFOLvQBXOXp',
#      'name': 'Major Lazer',
#      'type': 'artist',
#      'uri': 'spotify:artist:738wLrAtLtCtFOLvQBXOXp'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1vyhD5VmyZ7KMfW5gqLgo5'},
#      'href': 'https://api.spotify.com/v1/artists/1vyhD5VmyZ7KMfW5gqLgo5',
#      'id': '1vyhD5VmyZ7KMfW5gqLgo5',
#      'name': 'J Balvin',
#      'type': 'artist',
#      'uri': 'spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2oQX8QiMXOyuqbcZEFsZfm'},
#      'href': 'https://api.spotify.com/v1/artists/2oQX8QiMXOyuqbcZEFsZfm',
#      'id': '2oQX8QiMXOyuqbcZEFsZfm',
#      'name': 'El Alfa',
#      'type': 'artist',
#      'uri': 'spotify:artist:2oQX8QiMXOyuqbcZEFsZfm'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5fMUXHkw8R8eOP2RNVYEZX'},
#      'href': 'https://api.spotify.com/v1/artists/5fMUXHkw8R8eOP2RNVYEZX',
#      'id': '5fMUXHkw8R8eOP2RNVYEZX',
#      'name': 'Diplo',
#      'type': 'artist',
#      'uri': 'spotify:artist:5fMUXHkw8R8eOP2RNVYEZX'}],
#    'available_markets': ['CA',
#     'HK',
#     'ID',
#     'IL',
#     'IN',
#     'MX',
#     'MY',
#     'PH',
#     'SG',
#     'TH',
#     'TW',
#     'US',
#     'VN'],
#    'disc_number': 1,
#    'duration_ms': 169997,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMUY41800271'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/13HgktGt4RdYj0QmF1ELZO'},
#    'href': 'https://api.spotify.com/v1/tracks/13HgktGt4RdYj0QmF1ELZO',
#    'id': '13HgktGt4RdYj0QmF1ELZO',
#    'is_local': False,
#    'name': 'Que Calor (feat. J Balvin & El Alfa)',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/739d62016c50c956736488df6707f3a000eddaaa?cid=d4f68c3fcfdb402caeae8d1e3eea901d',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:13HgktGt4RdYj0QmF1ELZO'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/48zixAu4wMDZwpVbOenDU7'},
#       'href': 'https://api.spotify.com/v1/artists/48zixAu4wMDZwpVbOenDU7',
#       'id': '48zixAu4wMDZwpVbOenDU7',
#       'name': 'Grupo Cañaveral De Humberto Pabón',
#       'type': 'artist',
#       'uri': 'spotify:artist:48zixAu4wMDZwpVbOenDU7'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0enYFc2pFSAqZ53enjSU5r'},
#     'href': 'https://api.spotify.com/v1/albums/0enYFc2pFSAqZ53enjSU5r',
#     'id': '0enYFc2pFSAqZ53enjSU5r',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27364fd856aaae57a585c962c87',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0264fd856aaae57a585c962c87',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485164fd856aaae57a585c962c87',
#       'width': 64}],
#     'name': 'Grupo Cañaveral, Vol. 3',
#     'release_date': '1997-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0enYFc2pFSAqZ53enjSU5r'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/48zixAu4wMDZwpVbOenDU7'},
#      'href': 'https://api.spotify.com/v1/artists/48zixAu4wMDZwpVbOenDU7',
#      'id': '48zixAu4wMDZwpVbOenDU7',
#      'name': 'Grupo Cañaveral De Humberto Pabón',
#      'type': 'artist',
#      'uri': 'spotify:artist:48zixAu4wMDZwpVbOenDU7'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 238236,
#    'explicit': False,
#    'external_ids': {'isrc': 'MXF331110553'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1JO6kEdXrxBq9QobefZg0H'},
#    'href': 'https://api.spotify.com/v1/tracks/1JO6kEdXrxBq9QobefZg0H',
#    'id': '1JO6kEdXrxBq9QobefZg0H',
#    'is_local': False,
#    'name': 'Tiene Espinas El Rosal',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4b3174cd9f79c4cfbc123a6ae1ee6a4eaa374fb5?cid=d4f68c3fcfdb402caeae8d1e3eea901d',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:1JO6kEdXrxBq9QobefZg0H'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tJnB0s6c3oXPq1SCCavnd'},
#       'href': 'https://api.spotify.com/v1/artists/3tJnB0s6c3oXPq1SCCavnd',
#       'id': '3tJnB0s6c3oXPq1SCCavnd',
#       'name': 'Marco Antonio Solís',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tJnB0s6c3oXPq1SCCavnd'}],
#     'available_markets': ['AE',
#      'AR',
#      'AT',
#      'BH',
#      'BO',
#      'CL',
#      'CO',
#      'CR',
#      'DE',
#      'DO',
#      'DZ',
#      'EC',
#      'EG',
#      'ES',
#      'FR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IL',
#      'IS',
#      'JO',
#      'KW',
#      'LB',
#      'MA',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'SA',
#      'SV',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6335RBM5tYZal0oSZm6jvW'},
#     'href': 'https://api.spotify.com/v1/albums/6335RBM5tYZal0oSZm6jvW',
#     'id': '6335RBM5tYZal0oSZm6jvW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273daf2f76ae45d68acf3ed211a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02daf2f76ae45d68acf3ed211a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851daf2f76ae45d68acf3ed211a',
#       'width': 64}],
#     'name': 'Tu Amor O Tu Desprecio',
#     'release_date': '2003-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:6335RBM5tYZal0oSZm6jvW'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tJnB0s6c3oXPq1SCCavnd'},
#      'href': 'https://api.spotify.com/v1/artists/3tJnB0s6c3oXPq1SCCavnd',
#      'id': '3tJnB0s6c3oXPq1SCCavnd',
#      'name': 'Marco Antonio Solís',
#      'type': 'artist',
#      'uri': 'spotify:artist:3tJnB0s6c3oXPq1SCCavnd'}],
#    'available_markets': ['AE',
#     'AR',
#     'AT',
#     'BH',
#     'BO',
#     'CL',
#     'CO',
#     'CR',
#     'DE',
#     'DO',
#     'DZ',
#     'EC',
#     'EG',
#     'ES',
#     'FR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IL',
#     'IS',
#     'JO',
#     'KW',
#     'LB',
#     'MA',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'SA',
#     'SV',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 209506,
#    'explicit': False,
#    'external_ids': {'isrc': 'USFI20302292'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1Vy7WUJubV9JEoebuJ9dfe'},
#    'href': 'https://api.spotify.com/v1/tracks/1Vy7WUJubV9JEoebuJ9dfe',
#    'id': '1Vy7WUJubV9JEoebuJ9dfe',
#    'is_local': False,
#    'name': 'Más Que Tu Amigo',
#    'popularity': 75,
#    'preview_url': None,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:1Vy7WUJubV9JEoebuJ9dfe'}],
#  'total': 50,
#  'limit': 10,
#  'offset': 0,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?limit=10&offset=0&time_range=short_term',
#  'next': 'https://api.spotify.com/v1/me/top/tracks?limit=10&offset=10&time_range=short_term',
#  'previous': None}

# %%
top_tracks_short = sp.current_user_top_tracks(limit=20,offset=0,time_range='short_term')

# %%
type(top_tracks_short)
# Out:
# dict

# %%
def get_track_ids(time_frame):
    track_ids=[]
    for song in time_frame['items']:
        track_ids.append(song['id'])
    return track_ids

# %%
track_ids=get_track_ids(top_tracks_short)

# %%
track_ids
# Out:
# ['1DdrejuwM8C3ExsXaPAgF8',
#  '37kCg5izHEMZ66xGdMVG5L',
#  '6ab5dRx0VtGzMjUejMFI9u',
#  '03ITeFvMvTRpTC92WsQWw5',
#  '0Xfo7PfltbOrAiBs0eSCTH',
#  '0hp5IJ83YpnglsrvGfIhIN',
#  '0tsk2L7OXkyjn0X85B5Hhp',
#  '13HgktGt4RdYj0QmF1ELZO',
#  '1JO6kEdXrxBq9QobefZg0H',
#  '1Vy7WUJubV9JEoebuJ9dfe',
#  '1jBGM9PNMIZCe46WQ3i4ZB',
#  '1q0PYXTbDsirp2l74ng6pn',
#  '1q8NdCAQ9QUjpYiqzdd3mv',
#  '2Jz1X6ZB0gkkCVgmeVGVGp',
#  '2MazrWNhGfpvWnFcgGTyQZ',
#  '2Xh7dyCHCErCv3PmdVEGw4',
#  '2aAe07kXLPFefPuU7mLasv',
#  '2ctjDCCg1wHoQSjIJ8p6U4',
#  '33a2zTGZocgU9XVDDILHM3',
#  '35KmOEIUqAGn02t7n4qaIr']

# %%
track_id='1DdrejuwM8C3ExsXaPAgF8'

# %%
def get_track_features(id):
    meta = sp.track(id)
    #meta
    name=meta['name']
    album=meta['album']['name']
    artist=meta['album']['artists'][0]['name']
    spotify_url=meta['external_urls']['spotify']
    album_cover=meta['album']['images'][0]['url']
    track_info=[name,album,artist,spotify_url,album_cover]
    return track_info

# %%
get_track_features(track_id)
# Out:
# ['Noche de Travesura',
#  'Goldstar Music La Familia Reggaeton Hits',
#  'Héctor "El Father"',
#  'https://open.spotify.com/track/1DdrejuwM8C3ExsXaPAgF8',
#  'https://i.scdn.co/image/ab67616d0000b2736fed3daf437d6ba90a4f8707']

# %%
#loop over track ids
tracks=[]
for i in range(len(track_ids)):
    time.sleep(.5)
    track=get_track_features(track_ids[i])
    tracks.append(track)

# %%
tracks
# Out:
# [['Noche de Travesura',
#   'Goldstar Music La Familia Reggaeton Hits',
#   'Héctor "El Father"',
#   'https://open.spotify.com/track/1DdrejuwM8C3ExsXaPAgF8',
#   'https://i.scdn.co/image/ab67616d0000b2736fed3daf437d6ba90a4f8707'],
#  ['Oye Mujer',
#   'Oye Mujer',
#   'Raymix',
#   'https://open.spotify.com/track/37kCg5izHEMZ66xGdMVG5L',
#   'https://i.scdn.co/image/ab67616d0000b273cb610f9d9d31287af389de3b'],
#  ['Alma Enamorada',
#   'Chalino Sánchez con Banda Brava',
#   'Chalino Sanchez',
#   'https://open.spotify.com/track/6ab5dRx0VtGzMjUejMFI9u',
#   'https://i.scdn.co/image/ab67616d0000b2736036e5e9db7f583618242eb9'],
#  ['La Cumbia de los Monjes',
#   'Latino',
#   'Ritmo Y Sabor',
#   'https://open.spotify.com/track/03ITeFvMvTRpTC92WsQWw5',
#   'https://i.scdn.co/image/ab67616d0000b273e568a71f17b7df7e44156caa'],
#  ['¿Qué Tengo Que Hacer?',
#   'Talento de Barrio',
#   'Daddy Yankee',
#   'https://open.spotify.com/track/0Xfo7PfltbOrAiBs0eSCTH',
#   'https://i.scdn.co/image/ab67616d0000b273522f64d160907ff8a7b61bc7'],
#  ['Rakata',
#   'KICK ii',
#   'Arca',
#   'https://open.spotify.com/track/0hp5IJ83YpnglsrvGfIhIN',
#   'https://i.scdn.co/image/ab67616d0000b273f9e8f3f889a24247b88cc4a2'],
#  ['Una Vaina Loca (feat. Fuego)',
#   'Boy Wonder Presents Chosen Few Urbano El Journey',
#   'Boy Wonder CF',
#   'https://open.spotify.com/track/0tsk2L7OXkyjn0X85B5Hhp',
#   'https://i.scdn.co/image/ab67616d0000b2736018a9cf19dd63e138222e45'],
#  ['Que Calor (feat. J Balvin & El Alfa)',
#   'Music Is The Weapon (Reloaded)',
#   'Major Lazer',
#   'https://open.spotify.com/track/13HgktGt4RdYj0QmF1ELZO',
#   'https://i.scdn.co/image/ab67616d0000b273ff1a90a3234b2b344712ff42'],
#  ['Tiene Espinas El Rosal',
#   'Grupo Cañaveral, Vol. 3',
#   'Grupo Cañaveral De Humberto Pabón',
#   'https://open.spotify.com/track/1JO6kEdXrxBq9QobefZg0H',
#   'https://i.scdn.co/image/ab67616d0000b27364fd856aaae57a585c962c87'],
#  ['Más Que Tu Amigo',
#   'Tu Amor O Tu Desprecio',
#   'Marco Antonio Solís',
#   'https://open.spotify.com/track/1Vy7WUJubV9JEoebuJ9dfe',
#   'https://i.scdn.co/image/ab67616d0000b273daf2f76ae45d68acf3ed211a'],
#  ['Entre Rejas',
#   'El Burro Leñero',
#   'Lisandro Meza Y Su Conjunto',
#   'https://open.spotify.com/track/1jBGM9PNMIZCe46WQ3i4ZB',
#   'https://i.scdn.co/image/ab67616d0000b273b9483e270bdb72ac8c730eef'],
#  ['In Da Getto',
#   'JOSE',
#   'J Balvin',
#   'https://open.spotify.com/track/1q0PYXTbDsirp2l74ng6pn',
#   'https://i.scdn.co/image/ab67616d0000b273922a7339d969b5f0262580f5'],
#  ['Atrévete-Te-Te',
#   'Calle 13 (Explicit Version)',
#   'Calle 13',
#   'https://open.spotify.com/track/1q8NdCAQ9QUjpYiqzdd3mv',
#   'https://i.scdn.co/image/ab67616d0000b273bf3d37f1fd6a7e2cb5fd1487'],
#  ['Na De Na',
#   'Showtime',
#   'Angel Y Khriz',
#   'https://open.spotify.com/track/2Jz1X6ZB0gkkCVgmeVGVGp',
#   'https://i.scdn.co/image/ab67616d0000b27398cc17c2d48595067de30578'],
#  ['Cumbia del Amor',
#   '17 Éxitos',
#   'Lisandro Meza',
#   'https://open.spotify.com/track/2MazrWNhGfpvWnFcgGTyQZ',
#   'https://i.scdn.co/image/ab67616d0000b273a7012ea20b4691d1e4eb157c'],
#  ['Rabiosa (feat. Pitbull)',
#   'Sale el Sol',
#   'Shakira',
#   'https://open.spotify.com/track/2Xh7dyCHCErCv3PmdVEGw4',
#   'https://i.scdn.co/image/ab67616d0000b2734214ddc9e33e76de6a8ee888'],
#  ['Por Que No Te Pones En 4?',
#   'Por Que No Te Pones En 4?',
#   'Pablito Mix',
#   'https://open.spotify.com/track/2aAe07kXLPFefPuU7mLasv',
#   'https://i.scdn.co/image/ab67616d0000b2739ea681ae28ccb395bf418aab'],
#  ['Candy',
#   'Love And Sex',
#   'Plan B',
#   'https://open.spotify.com/track/2ctjDCCg1wHoQSjIJ8p6U4',
#   'https://i.scdn.co/image/ab67616d0000b273bd88e490e34600dad8add229'],
#  ['La Despedida',
#   'Mundial (Deluxe Version)',
#   'Daddy Yankee',
#   'https://open.spotify.com/track/33a2zTGZocgU9XVDDILHM3',
#   'https://i.scdn.co/image/ab67616d0000b273d55d06f510870ea67dccbb2e'],
#  ['Morado',
#   'Colores',
#   'J Balvin',
#   'https://open.spotify.com/track/35KmOEIUqAGn02t7n4qaIr',
#   'https://i.scdn.co/image/ab67616d0000b27335692baca45542527d742d0d']]

# %%
#create dataframe
df= pd.DataFrame(tracks, columns= ['name','album','artist','spotify_url','album_cover'])
df.head(5)
# Out:
#                       name                                     album  \
# 0       Noche de Travesura  Goldstar Music La Familia Reggaeton Hits
# 1                Oye Mujer                                 Oye Mujer
# 2           Alma Enamorada           Chalino Sánchez con Banda Brava
# 3  La Cumbia de los Monjes                                    Latino
# 4    ¿Qué Tengo Que Hacer?                         Talento de Barrio
#
#                artist                                        spotify_url  \
# 0  Héctor "El Father"  https://open.spotify.com/track/1DdrejuwM8C3Exs...
# 1              Raymix  https://open.spotify.com/track/37kCg5izHEMZ66x...
# 2     Chalino Sanchez  https://open.spotify.com/track/6ab5dRx0VtGzMjU...
# 3       Ritmo Y Sabor  https://open.spotify.com/track/03ITeFvMvTRpTC9...
# 4        Daddy Yankee  https://open.spotify.com/track/0Xfo7PfltbOrAiB...
#
#                                          album_cover
# 0  https://i.scdn.co/image/ab67616d0000b2736fed3d...
# 1  https://i.scdn.co/image/ab67616d0000b273cb610f...
# 2  https://i.scdn.co/image/ab67616d0000b2736036e5...
# 3  https://i.scdn.co/image/ab67616d0000b273e568a7...
# 4  https://i.scdn.co/image/ab67616d0000b273522f64...

# %%
pip install gspread
# Out:
# Collecting gspread
#   Using cached gspread-5.10.0-py3-none-any.whl (44 kB)
# Collecting google-auth>=1.12.0
#   Using cached google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
# Collecting google-auth-oauthlib>=0.4.1
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\riera\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\riera\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (1.16.0)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: urllib3<2.0 in c:\users\riera\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (1.26.11)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\riera\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\riera\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2022.9.14)
# Installing collected packages: rsa, oauthlib, cachetools, requests-oauthlib, google-auth, google-auth-oauthlib, gspread
# Successfully installed cachetools-5.3.1 google-auth-2.22.0 google-auth-oauthlib-1.0.0 gspread-5.10.0 oauthlib-3.2.2 requests-oauthlib-1.3.1 rsa-4.9
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /simple/gspread/

# %%
import gspread

# %%
gc = gspread.service_account(filename='C:\\Users\\riera\\Downloads\\my-spotify-wrapped-test-397100-2f9201a47fa6.json')

# %%
sh = gc.open('My Spotify Wrapped')

# %%
worksheet = sh.worksheet('short_term')

# %%
val=worksheet.acell('B5').value

# %%
val

# %%
#worksheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())

# %%
#insert into sheet
def insert_to_gsheet(track_ids):
    # loop over track ids
    tracks=[]
    for i in range(len(track_ids)):
        time.sleep(.5)
        track=get_track_features(track_ids[i])
        tracks.append(track)
    # create dataset
    df = pd.DataFrame(tracks,columns=['name','album','artist','spotify_url','album_cover'])
    #inserting into google sheets
    gc = gspread.service_account(filename='C:\\Users\\riera\\Downloads\\my-spotify-wrapped-test-397100-2f9201a47fa6.json')
    sh = gc.open('My Spotify Wrapped')
    worksheet = sh.worksheet(f'{time_period}')
    worksheet.update([df.columns.values.tolist()] + df.values.tolist())
    print('Done')

# %%
time_ranges= ['short_term','medium_term','long_term']
for time_period in time_ranges:
    top_tracks = sp.current_user_top_tracks(limit=20,offset=0,time_ranges=time_period)
    track_ids=get_track_ids(top_tracks)
    insert_to_gsheet(track_ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17472\3023569518.py in <module>
#       1 time_ranges= ['short_term','medium_term','long_term']
#       2 for time_period in time_ranges:
# ----> 3     top_tracks = sp.current_user_top_tracks(limit=20,offset=0,time_ranges=time_period)
#       4     track_ids=get_track_ids(top_tracks)
#       5     insert_to_gsheet(track_ids)
#
# NameError: name 'sp' is not defined

# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\riera\anaconda3\lib\site-packages (2.23.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\riera\anaconda3\lib\site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: redis>=3.5.3 in c:\users\riera\anaconda3\lib\site-packages (from spotipy) (5.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\riera\anaconda3\lib\site-packages (from spotipy) (1.26.11)
# Requirement already satisfied: six>=1.15.0 in c:\users\riera\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\riera\anaconda3\lib\site-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID, 
                                               client_secret=SPOTIPY_CLIENT_SECRET, 
                                               redirect_uri=SPOTIPY_REDIRECT_URI, 
                                               scope=SCOPE))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17472\1042556961.py in <module>
# ----> 1 sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID,
#       2                                                client_secret=SPOTIPY_CLIENT_SECRET,
#       3                                                redirect_uri=SPOTIPY_REDIRECT_URI,
#       4                                                scope=SCOPE))
#
# NameError: name 'spotipy' is not defined

# %%
import requests
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time
import datetime

# %%
SPOTIPY_CLIENT_ID = 'd4f68c3fcfdb402caeae8d1e3eea901d'
SPOTIPY_CLIENT_SECRET = '20fe78aa54244addb74de96acda5eb65'
SPOTIPY_REDIRECT_URI = 'http://127.0.0.1:9090'
SCOPE = 'user-top-read'

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID, 
                                               client_secret=SPOTIPY_CLIENT_SECRET, 
                                               redirect_uri=SPOTIPY_REDIRECT_URI, 
                                               scope=SCOPE))

# %%
top_tracks_short = sp.current_user_top_tracks(limit=10,offset=0,time_range='short_term')

# %%
def get_track_ids(time_frame):
    track_ids=[]
    for song in time_frame['items']:
        track_ids.append(song['id'])
    return track_ids

# %%
track_ids=get_track_ids(top_tracks_short)

# %%
track_id='1DdrejuwM8C3ExsXaPAgF8'

# %%
def get_track_features(id):
    meta = sp.track(id)
    #meta
    name=meta['name']
    album=meta['album']['name']
    artist=meta['album']['artists'][0]['name']
    spotify_url=meta['external_urls']['spotify']
    album_cover=meta['album']['images'][0]['url']
    track_info=[name,album,artist,spotify_url,album_cover]
    return track_info

# %%
get_track_features(track_id)
# Out:
# ['Noche de Travesura',
#  'Goldstar Music La Familia Reggaeton Hits',
#  'Héctor "El Father"',
#  'https://open.spotify.com/track/1DdrejuwM8C3ExsXaPAgF8',
#  'https://i.scdn.co/image/ab67616d0000b2736fed3daf437d6ba90a4f8707']

# %%
#loop over track ids
tracks=[]
for i in range(len(track_ids)):
    time.sleep(.5)
    track=get_track_features(track_ids[i])
    tracks.append(track)

# %%
#create dataframe
df= pd.DataFrame(tracks, columns= ['name','album','artist','spotify_url','album_cover'])
df.head(5)
# Out:
#                       name                                     album  \
# 0       Noche de Travesura  Goldstar Music La Familia Reggaeton Hits
# 1                Oye Mujer                                 Oye Mujer
# 2           Alma Enamorada           Chalino Sánchez con Banda Brava
# 3  La Cumbia de los Monjes                                    Latino
# 4    ¿Qué Tengo Que Hacer?                         Talento de Barrio
#
#                artist                                        spotify_url  \
# 0  Héctor "El Father"  https://open.spotify.com/track/1DdrejuwM8C3Exs...
# 1              Raymix  https://open.spotify.com/track/37kCg5izHEMZ66x...
# 2     Chalino Sanchez  https://open.spotify.com/track/6ab5dRx0VtGzMjU...
# 3       Ritmo Y Sabor  https://open.spotify.com/track/03ITeFvMvTRpTC9...
# 4        Daddy Yankee  https://open.spotify.com/track/0Xfo7PfltbOrAiB...
#
#                                          album_cover
# 0  https://i.scdn.co/image/ab67616d0000b2736fed3d...
# 1  https://i.scdn.co/image/ab67616d0000b273cb610f...
# 2  https://i.scdn.co/image/ab67616d0000b2736036e5...
# 3  https://i.scdn.co/image/ab67616d0000b273e568a7...
# 4  https://i.scdn.co/image/ab67616d0000b273522f64...

# %%
pip install gspread
# Out:
# Requirement already satisfied: gspread in c:\users\riera\anaconda3\lib\site-packages (5.10.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\riera\anaconda3\lib\site-packages (from gspread) (1.0.0)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\riera\anaconda3\lib\site-packages (from gspread) (2.22.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\riera\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\riera\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\riera\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (1.26.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\riera\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\riera\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\riera\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\riera\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\riera\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in c:\users\riera\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\riera\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2022.9.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread

# %%
gc = gspread.service_account(filename='C:\\Users\\riera\\Downloads\\my-spotify-wrapped-test-397100-2f9201a47fa6.json')

# %%
sh = gc.open('My Spotify Wrapped')

# %%
worksheet = sh.worksheet('short_term')

# %%
val=worksheet.acell('B5').value

# %%
#insert into sheet
def insert_to_gsheet(track_ids):
    # loop over track ids
    tracks=[]
    for i in range(len(track_ids)):
        time.sleep(.5)
        track=get_track_features(track_ids[i])
        tracks.append(track)
    # create dataset
    df = pd.DataFrame(tracks,columns=['name','album','artist','spotify_url','album_cover'])
    #inserting into google sheets
    gc = gspread.service_account(filename='C:\\Users\\riera\\Downloads\\my-spotify-wrapped-test-397100-2f9201a47fa6.json')
    sh = gc.open('My Spotify Wrapped')
    worksheet = sh.worksheet(f'{time_period}')
    worksheet.update([df.columns.values.tolist()] + df.values.tolist())
    print('Done')

# %%
time_ranges= ['short_term','medium_term','long_term']
for time_period in time_ranges:
    top_tracks = sp.current_user_top_tracks(limit=20,offset=0,time_range=time_period)
    track_ids=get_track_ids(top_tracks)
    insert_to_gsheet(track_ids)
# Out:
# C:\Users\riera\anaconda3\lib\site-packages\gspread\worksheet.py:1046: UserWarning: [Deprecated][in version 6.0.0]: method signature will change to: 'Worksheet.update(value = [[]], range_name=)' arguments 'range_name' and 'values' will swap, values will be mandatory of type: 'list(list(...))'
#   warnings.warn(
# Done
# C:\Users\riera\anaconda3\lib\site-packages\gspread\worksheet.py:1046: UserWarning: [Deprecated][in version 6.0.0]: method signature will change to: 'Worksheet.update(value = [[]], range_name=)' arguments 'range_name' and 'values' will swap, values will be mandatory of type: 'list(list(...))'
#   warnings.warn(
# Done
# C:\Users\riera\anaconda3\lib\site-packages\gspread\worksheet.py:1046: UserWarning: [Deprecated][in version 6.0.0]: method signature will change to: 'Worksheet.update(value = [[]], range_name=)' arguments 'range_name' and 'values' will swap, values will be mandatory of type: 'list(list(...))'
#   warnings.warn(
# Done
